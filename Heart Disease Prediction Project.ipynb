# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("HeartDisease.csv")
df
# Out:
#      age  gender  chest_pain  rest_bps  cholestrol  fasting_blood_sugar  \
# 0     63       1           3       145         233                    1
# 1     37       1           2       130         250                    0
# 2     41       0           1       130         204                    0
# 3     56       1           1       120         236                    0
# 4     57       0           0       120         354                    0
# ..   ...     ...         ...       ...         ...                  ...
# 298   57       0           0       140         241                    0
# 299   45       1           3       110         264                    0
# 300   68       1           0       144         193                    1
# 301   57       1           0       130         131                    0
# 302   57       0           1       130         236                    0
#
#      rest_ecg  thalach  exer_angina  old_peak  slope  ca  thalassemia  target
# ...

# %%
#Here we are using the pandas read_csv function to read the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  303 non-null    int64
#  1   gender               303 non-null    int64
#  2   chest_pain           303 non-null    int64
#  3   rest_bps             303 non-null    int64
#  4   cholestrol           303 non-null    int64
#  5   fasting_blood_sugar  303 non-null    int64
#  6   rest_ecg             303 non-null    int64
#  7   thalach              303 non-null    int64
#  8   exer_angina          303 non-null    int64
#  9   old_peak             303 non-null    float64
#  10  slope                303 non-null    int64
#  11  ca                   303 non-null    int64
#  12  thalassemia          303 non-null    int64
#  13  target               303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
#Out of 14 features, we have 13 int types and only one float data type.

# %%
df.describe()
# Out:
#               age      gender  chest_pain    rest_bps  cholestrol  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026
# std      9.082101    0.466011    1.032052   17.538143   51.830751
# min     29.000000    0.000000    0.000000   94.000000  126.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000
# max     77.000000    1.000000    3.000000  200.000000  564.000000
#
#        fasting_blood_sugar    rest_ecg     thalach  exer_angina    old_peak  \
# count           303.000000  303.000000  303.000000   303.000000  303.000000
# mean              0.148515    0.528053  149.646865     0.326733    1.039604
# std               0.356198    0.525860   22.905161     0.469794    1.161075
# ...

# %%
#Here we are getting statistical information about dataset.

# %%
df.shape
# Out:
# (303, 14)

# %%
#We have a dataset with 303 rows which indicates a smaller set of data.

# %%
df.isnull().sum()
# Out:
# age                    0
# gender                 0
# chest_pain             0
# rest_bps               0
# cholestrol             0
# fasting_blood_sugar    0
# rest_ecg               0
# thalach                0
# exer_angina            0
# old_peak               0
# slope                  0
# ca                     0
# thalassemia            0
# target                 0
# dtype: int64

# %%
# Dataset does not contain any null values and duplicates.

# %%
features=df.iloc[:,:-1]
target=df.iloc[:,-1]

# %%
features.columns
# Out:
# Index(['age', 'gender', 'chest_pain', 'rest_bps', 'cholestrol',
#        'fasting_blood_sugar', 'rest_ecg', 'thalach', 'exer_angina', 'old_peak',
#        'slope', 'ca', 'thalassemia'],
#       dtype='object')

# %%
# Correlation Matrix

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
# chest_pain, rest_ecg, thalach, slope are positively correlated with the target feature.
# Other features are negatively correlated with the target feature.

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df,x="age")
plt.show()

# %%
# Here we can see that the 58 age column has the highest frequency.

# %%
minAge=min(df.age)
maxAge=max(df.age)
meanAge=df.age.mean()
print('Min Age :',minAge)
print('Max Age :',maxAge)
print('Mean Age :',meanAge)
# Out:
# Min Age : 29
# Max Age : 77
# Mean Age : 54.366336633663366

# %%
# Range of age in the dataset

# %%
Young=df[(df.age>=29)&(df.age<40)]
Middle=df[(df.age>=40)&(df.age<55)]
Elder=df[(df.age>55)]

# %%
# Age divided into 3 parts that is Young , Middle and Elder

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=['young','middle','elder'],y=[len(Young),len(Middle),len(Elder)])
plt.show()

# %%
# Here we can see that elder people are most affected by heart disease and young ones are least affected.

# %%
colors=['blue','orange','green']
plt.figure(figsize=(15,10))
plt.pie([len(Young),len(Middle),len(Elder)],labels=['young','middle','elder'],colors=colors,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1a36b20df30>,
# ...
#  [Text(1.0840703088664039, 0.18652497268274834, 'young'),
#   Text(-0.14599805795280732, 1.0902681170583723, 'middle'),
#   Text(-0.04099093501705036, -1.099235981601052, 'elder')],
#  [Text(0.5913110775634929, 0.10174089419058999, '5.4%'),
#   Text(-0.07963530433789488, 0.5946917002136576, '43.4%'),
#   Text(-0.02235869182748201, -0.5995832626914828, '51.2%')])

# %%
# we will plot this pie to show the percentage of heart disease afftected in young,middle and elder ones.
# Pie chart indicates that the elder people are most afftected that is 51.2% and young ones are least affected that is 5.4%.

# %%
pd.crosstab(df.gender,df.target).plot(kind="bar",figsize=(15,8))
plt.title('Heart Disease Frequency for gender')
plt.xlabel("gender(female=0 , male=1)")
plt.legend(["Having Disease", "not having Disease"])
plt.ylabel('Frequency')
plt.show()

# %%
# value is higher in case of males

# %%
pd.crosstab(df.chest_pain,df.target).plot(kind="bar",figsize=(15,6))
plt.title('Heart disease according to Chest Pain')
plt.xlabel('Chest Pain Type')
plt.ylabel('Disease or Not')
plt.show()

# %%
# Analysing chest_pain vs target column
# People having the least chest pain are not likely to have heart disease.
# People having severe chest pain are likely to have heart disease.

# %%
# Data Modeling

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(features,target,test_size=0.25,random_state=40)

# %%
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((227, 13), (76, 13), (227,), (76,))

# %%
# Algorithm Implementation

# %%
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
model= DecisionTreeClassifier(max_depth=5,criterion="entropy")
model.fit(xtrain,ytrain)
ypred=model.predict(xtest)

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
a=accuracy_score(ytest,ypred)
cm=confusion_matrix(ytest,ypred)
cr=classification_report(ytest,ypred)
print(a)
print(cm)
print(cr)
# Out:
# 0.8289473684210527
# [[30  4]
#  [ 9 33]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82        34
#            1       0.89      0.79      0.84        42
#
#     accuracy                           0.83        76
#    macro avg       0.83      0.83      0.83        76
# weighted avg       0.84      0.83      0.83        76

# %%
# we get the accuracy of the Decision Tree classifier is about 83%.

# %%
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=100,max_depth=5)
model.fit(xtrain,ytrain)
ypred=model.predict(xtest)

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
a=accuracy_score(ytest,ypred)
cm=confusion_matrix(ytest,ypred)
cr=classification_report(ytest,ypred)
print(a)
print(cm)
print(cr)
# Out:
# 0.8947368421052632
# [[29  5]
#  [ 3 39]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88        34
#            1       0.89      0.93      0.91        42
#
#     accuracy                           0.89        76
#    macro avg       0.90      0.89      0.89        76
# weighted avg       0.90      0.89      0.89        76

# %%
#  we can get the accuracy of the Random Forest classifier is about 89%.

# %%
from sklearn.svm import SVC
svm=SVC(kernel="linear")
svm.fit(xtrain,ytrain)
ypred=model.predict(xtest)

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
a=accuracy_score(ytest,ypred)
cm=confusion_matrix(ytest,ypred)
cr=classification_report(ytest,ypred)
print(a)
print(cm)
print(cr)
# Out:
# 0.868421052631579
# [[28  6]
#  [ 4 38]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85        34
#            1       0.86      0.90      0.88        42
#
#     accuracy                           0.87        76
#    macro avg       0.87      0.86      0.87        76
# weighted avg       0.87      0.87      0.87        76

# %%
# we get the accuracy of the Support Vector Machine classifier is about 86%.

# %%
'''
We have applied three machine learning algorithms like Decision Tree, Random Forest Classifier
and Support Vector Machine.
we got , Decision Trees as 83%
Random Forest as 89%, 
Support Vector Machines as 86% 
We can conclude that the Random Forest algorithm is the best algorithm for our model with the 
highest accuracy around 89%.
'''
